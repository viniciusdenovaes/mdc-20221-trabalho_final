# %% [markdown]
# Instruções iniciais
#
# Abra os links dos dados:
#
# https://drive.google.com/drive/folders/19gc0iSvxhdvO7lqiq_gSd1ILj4qEhqAd?usp=sharing
#
# Clique em "Adicionar atalho ao Drive"

# %% [markdown]
# Montar o drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Visualizar as pastas com os arquivos de Predição de Atributos Visuais

# %%
# !ls "/content/drive/MyDrive/Predição de Atributos Visuais/"
# Out:
# annotations  holdout_split  imageAlignedLD  imageLD

# %% [markdown]
# Visualizar a lista de imagens nos arquivos test.txt e training.txt para montar o diretório training e test com as imagens da pasta imageLD

# %%
# !ls "/content/drive/MyDrive/Predição de Atributos Visuais/holdout_split/"
# Out:
# test.txt  training.txt

# %%
# !ls "/content/drive/MyDrive/Predição de Atributos Visuais/imageLD/"
# Out:
# 00000064  00001308  00009483  00016761	00017709  00018959  00019919  90000005
# 00000090  00005381  00010091  00016845	00018071  00018962  00019920  90000006
# 00000162  00007202  00010098  00017609	00018086  00018963  00021901  90000007
# 00000260  00007371  00010180  00017613	00018118  00018964  00022785  90000008
# 00000270  00008205  00010302  00017627	00018347  00018965  00023240  90000009
# 00000325  00008346  00010430  00017632	00018478  00018997  00023943  90000010
# 00000384  00008383  00010606  00017640	00018505  00019000  00023944  90000011
# 00000398  00008402  00010780  00017658	00018515  00019246  00023945  90000012
# 00000441  00008616  00010801  00017659	00018680  00019388  00023946  90000013
# 00000536  00008728  00010917  00017660	00018726  00019394  00023947  90000014
# 00000573  00008915  00011616  00017663	00018759  00019435  90000002
# 00001048  00009053  00014842  00017664	00018769  00019827  90000003
# ...

# %% [markdown]
# Listar as imagens do arquivo test.txt

# %%
# !cat "/content/drive/MyDrive/Predição de Atributos Visuais/holdout_split/test.txt"
# Out:
# 00000090/1.jpg
# 00000090/10.jpg
# 00000090/104.jpg
# 00000090/105.jpg
# 00000090/107.jpg
# 00000090/11.jpg
# 00000090/111.jpg
# 00000090/113.jpg
# 00000090/114.jpg
# 00000090/118.jpg
# 00000090/120.jpg
# 00000090/123.jpg
# 00000090/124.jpg
# 00000090/125.jpg
# 00000090/128.jpg
# 00000090/13.jpg
# 00000090/133.jpg
# 00000090/135.jpg
# 00000090/138.jpg
# 00000090/14.jpg
# 00000090/142.jpg
# 00000090/144.jpg
# 00000090/147.jpg
# 00000090/149.jpg
# 00000090/15.jpg
# 00000090/152.jpg
# 00000090/153.jpg
# 00000090/156.jpg
# 00000090/158.jpg
# 00000090/16.jpg
# 00000090/160.jpg
# 00000090/165.jpg
# 00000090/167.jpg
# 00000090/168.jpg
# 00000090/17.jpg
# 00000090/171.jpg
# 00000090/174.jpg
# 00000090/182.jpg
# 00000090/188.jpg
# 00000090/19.jpg
# 00000090/192.jpg
# 00000090/195.jpg
# 00000090/197.jpg
# 00000090/201.jpg
# 00000090/206.jpg
# 00000090/21.jpg
# 00000090/210.jpg
# 00000090/211.jpg
# 00000090/22.jpg
# 00000090/228.jpg
# 00000090/23.jpg
# 00000090/231.jpg
# 00000090/235.jpg
# ...

# %% [markdown]
# Listar as imagens do arquivo training.txt

# %%
# !cat "/content/drive/MyDrive/Predição de Atributos Visuais/holdout_split/training.txt"
# Out:
# 00000064/1.jpg
# 00000064/101.jpg
# 00000064/106.jpg
# 00000064/107.jpg
# 00000064/109.jpg
# 00000064/111.jpg
# 00000064/112.jpg
# 00000064/114.jpg
# 00000064/115.jpg
# 00000064/117.jpg
# 00000064/118.jpg
# 00000064/120.jpg
# 00000064/124.jpg
# 00000064/125.jpg
# 00000064/126.jpg
# 00000064/127.jpg
# 00000064/128.jpg
# 00000064/129.jpg
# 00000064/131.jpg
# 00000064/134.jpg
# 00000064/136.jpg
# 00000064/137.jpg
# 00000064/138.jpg
# 00000064/141.jpg
# 00000064/142.jpg
# 00000064/144.jpg
# 00000064/146.jpg
# 00000064/149.jpg
# 00000064/152.jpg
# 00000064/153.jpg
# 00000064/156.jpg
# 00000064/16.jpg
# 00000064/161.jpg
# 00000064/165.jpg
# 00000064/167.jpg
# 00000064/17.jpg
# 00000064/178.jpg
# 00000064/19.jpg
# 00000064/190.jpg
# 00000064/191.jpg
# 00000064/193.jpg
# 00000064/195.jpg
# 00000064/207.jpg
# 00000064/220.jpg
# 00000064/225.jpg
# 00000064/23.jpg
# 00000064/231.jpg
# 00000064/24.jpg
# 00000064/245.jpg
# 00000064/25.jpg
# 00000064/251.jpg
# 00000064/26.jpg
# 00000064/261.jpg
# ...

# %% [markdown]
# Descrição dos atributos que serão utilizados no projeto

# %%
# !cat "/content/drive/MyDrive/Predição de Atributos Visuais/annotations/attributes.txt"
# Out:
# dirty
# daylight
# night
# sunrisesunset
# dawndusk
# sunny
# clouds
# fog
# storm
# snow
# warm
# cold
# busy
# beautiful
# flowers
# spring
# summer
# autumn
# winter
# glowing
# colorful
# dull
# rugged
# midday
# dark
# bright
# dry
# moist
# windy
# rain
# ice
# cluttered
# soothing
# stressful
# exciting
# sentimental
# mysterious
# boring
# gloomy
# lush

# %% [markdown]
# Importar os arquivos da lista test.txt para a pasta do Drive /content/drive/MyDrive/Projeto_Final/test

# %%
import os

filenames = []

for file in os.listdir("/content/drive/MyDrive/Predição de Atributos Visuais/holdout_split/"):
  filenames.append(file)

print(filenames)
# Out:
# ['training.txt', 'test.txt']

# %%
pasta_origem = "/content/drive/MyDrive/Predição de Atributos Visuais/holdout_split/test.txt"

pasta_destino = "/content/drive/MyDrive/Projeto_Final/test.txt"

# %%
# !ls "/content/drive/MyDrive/Predição de Atributos Visuais/imageLD/"
# Out:
# 00000064  00001308  00009483  00016761	00017709  00018959  00019919  90000005
# 00000090  00005381  00010091  00016845	00018071  00018962  00019920  90000006
# 00000162  00007202  00010098  00017609	00018086  00018963  00021901  90000007
# 00000260  00007371  00010180  00017613	00018118  00018964  00022785  90000008
# 00000270  00008205  00010302  00017627	00018347  00018965  00023240  90000009
# 00000325  00008346  00010430  00017632	00018478  00018997  00023943  90000010
# 00000384  00008383  00010606  00017640	00018505  00019000  00023944  90000011
# 00000398  00008402  00010780  00017658	00018515  00019246  00023945  90000012
# 00000441  00008616  00010801  00017659	00018680  00019388  00023946  90000013
# 00000536  00008728  00010917  00017660	00018726  00019394  00023947  90000014
# 00000573  00008915  00011616  00017663	00018759  00019435  90000002
# 00001048  00009053  00014842  00017664	00018769  00019827  90000003
# ...

# %%
import os
import shutil
from glob import glob

from os import path

if path.exists('/content/drive/MyDrive/Projeto_Final/test'):
    shutil.rmtree('test')

os.mkdir('/content/drive/MyDrive/Projeto_Final/test')

for file in glob('/content/drive/MyDrive/Predição de Atributos Visuais/holdout_split/test.txt'):
  with open (file) as test.txt:
    shutil.copy(file, 'test')
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-56-146ef14acf65> in <module>()
#       6
#       7 if path.exists('/content/drive/MyDrive/Projeto_Final/test'):
# ----> 8     shutil.rmtree('test')
#       9
#      10 os.mkdir('/content/drive/MyDrive/Projeto_Final/test')
#
# /usr/lib/python3.7/shutil.py in rmtree(path, ignore_errors, onerror)
#     492         try:
#     493             if os.path.samestat(orig_st, os.fstat(fd)):
# --> 494                 _rmtree_safe_fd(fd, path, onerror)
#     495                 try:
#     496                     os.rmdir(path)
#
# /usr/lib/python3.7/shutil.py in _rmtree_safe_fd(topfd, path, onerror)
#     411     except OSError as err:
#     412         err.filename = path
# --> 413         onerror(os.scandir, path, sys.exc_info())
#     414         return
#     415     for entry in entries:
#
# ...

# %%
from pathlib import Path

for file in Path('/content/drive/MyDrive/Predição de Atributos Visuais/holdout_split').glob('*.txt'):

  print (file.read_text())
# Out:
# 00000064/1.jpg
# 00000064/101.jpg
# 00000064/106.jpg
# 00000064/107.jpg
# 00000064/109.jpg
# 00000064/111.jpg
# 00000064/112.jpg
# 00000064/114.jpg
# 00000064/115.jpg
# 00000064/117.jpg
# 00000064/118.jpg
# 00000064/120.jpg
# 00000064/124.jpg
# 00000064/125.jpg
# 00000064/126.jpg
# 00000064/127.jpg
# 00000064/128.jpg
# 00000064/129.jpg
# 00000064/131.jpg
# 00000064/134.jpg
# 00000064/136.jpg
# 00000064/137.jpg
# 00000064/138.jpg
# 00000064/141.jpg
# 00000064/142.jpg
# 00000064/144.jpg
# 00000064/146.jpg
# 00000064/149.jpg
# 00000064/152.jpg
# 00000064/153.jpg
# 00000064/156.jpg
# 00000064/16.jpg
# 00000064/161.jpg
# 00000064/165.jpg
# 00000064/167.jpg
# 00000064/17.jpg
# 00000064/178.jpg
# 00000064/19.jpg
# 00000064/190.jpg
# 00000064/191.jpg
# 00000064/193.jpg
# 00000064/195.jpg
# 00000064/207.jpg
# 00000064/220.jpg
# 00000064/225.jpg
# 00000064/23.jpg
# 00000064/231.jpg
# 00000064/24.jpg
# 00000064/245.jpg
# 00000064/25.jpg
# 00000064/251.jpg
# 00000064/26.jpg
# 00000064/261.jpg
# ...

# %% [markdown]
# Abrir o arquivo test.txt e copiar a pasta e arquivo test.txt

# %%
list(Path('/content/drive/MyDrive/Predição de Atributos Visuais/holdout_split/').glob('*.txt'))
# Out:
# [PosixPath('/content/drive/MyDrive/Predição de Atributos Visuais/holdout_split/training.txt'),
#  PosixPath('/content/drive/MyDrive/Predição de Atributos Visuais/holdout_split/test.txt')]
